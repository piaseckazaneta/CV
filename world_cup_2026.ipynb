# %% [markdown]
# <a href="https://colab.research.google.com/github/piaseckazaneta/CV/blob/master/world_cup_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install folium

# %%
import folium

# 1. Centering the map on North America
mapa = folium.Map(location=[39.8283, -98.5795], zoom_start=4, tiles="OpenStreetMap")

# 2. Colors configuration (Hexadecimal counterparts for standard Folium colors to use in HTML legend)
kolory_grup = {
    "Group A": {"folium": "blue", "hex": "#38AADD"},
    "Group B": {"folium": "green", "hex": "#72B026"},
    "Group C": {"folium": "orange", "hex": "#F69730"},
    "Group D": {"folium": "purple", "hex": "#D252B9"},
    "Group E": {"folium": "cadetblue", "hex": "#436978"},
    "Group F": {"folium": "pink", "hex": "#FF8E7F"},
    "Group G": {"folium": "lightblue", "hex": "#57BEEC"},
    "Group H": {"folium": "lightgreen", "hex": "#BBF970"},
    "Group I": {"folium": "black", "hex": "#303030"},
    "Group J": {"folium": "darkpurple", "hex": "#5B396B"},
    "Knockout Stage": {"folium": "red", "hex": "#D63E2A"}
}

# 3. Full dataset with English pop-ups, exact match dates, and stages
stadiony = [
    # --- USA ---
    {
        "nazwa": "MetLife Stadium (New York New Jersey)",
        "coords": [40.8135, -74.0745],
        "grupa": "Knockout Stage",
        "info": """<b>MetLife Stadium</b><br>
                   <b>Urban Context:</b> Deep suburbs (East Rutherford). Isolated corporate stadium wrapped in asphalt parking lots.<br>
                   <b>Key Matches:</b><br>
                   • June 13 & 16: Group Stage<br>
                   • June 27: Group Stage (Panama vs England)<br>
                   • June 30: Round of 32<br>
                   • July 5: Round of 16<br>
                   • July 11: Quarter-final<br>
                   • <b>July 19: THE FINAL 🏆</b>"""
    },
    {
        "nazwa": "SoFi Stadium (Los Angeles)",
        "coords": [33.9534, -118.3392],
        "grupa": "Group A",
        "info": """<b>SoFi Stadium</b><br>
                   <b>Urban Context:</b> Suburbs (Inglewood). Near LAX airport, integrated into a modern entertainment district rather than traditional downtown.<br>
                   <b>Key Matches:</b><br>
                   • June 12: Group Stage (USA opening match)<br>
                   • June 15, 18 & 21: Group Stage Matches<br>
                   • June 26: Group Stage (Turkey vs USA)<br>
                   • June 28: Round of 32<br>
                   • July 2: Round of 32<br>
                   • July 6: Round of 16<br>
                   • July 10: Quarter-final"""
    },
    {
        "nazwa": "Mercedes-Benz Stadium (Atlanta)",
        "coords": [33.7554, -84.4010],
        "grupa": "Group B",
        "info": """<b>Mercedes-Benz Stadium</b><br>
                   <b>Urban Context:</b> Strict Downtown. Excellent integration with public transit and city walkable infrastructure.<br>
                   <b>Key Matches:</b><br>
                   • June 15: Group Stage (Spain vs Cape Verde)<br>
                   • June 18, 21 & 24: Group Stage Matches<br>
                   • June 27: Round of 32<br>
                   • July 1: Round of 32<br>
                   • July 7: Round of 16<br>
                   • <b>July 15: Semi-final ⚽</b>"""
    },
    {
        "nazwa": "Hard Rock Stadium (Miami)",
        "coords": [25.9580, -80.2389],
        "grupa": "Group C",
        "info": """<b>Hard Rock Stadium</b><br>
                   <b>Urban Context:</b> Suburbs (Miami Gardens). Car-centric design located 20+ km away from Miami Beach.<br>
                   <b>Key Matches:</b><br>
                   • June 15: Group Stage (Saudi Arabia vs Uruguay)<br>
                   • June 21 & 24: Group Stage Matches<br>
                   • June 28: Group Stage (Colombia vs Portugal)<br>
                   • July 3: Round of 32<br>
                   • July 11: Quarter-final<br>
                   • July 18: Third-place play-off (Bronze Final)"""
    },
    {
        "nazwa": "Gillette Stadium (Boston)",
        "coords": [42.0909, -71.2643],
        "grupa": "Group D",
        "info": """<b>Gillette Stadium</b><br>
                   <b>Urban Context:</b> Extreme Suburbs (Foxborough). 50 km outside Boston. Hard to access without a car or event train.<br>
                   <b>Key Matches:</b><br>
                   • June 13: Group Stage (Haiti vs Scotland)<br>
                   • June 16, 19 & 23: Group Stage Matches<br>
                   • June 26: Group Stage (Norway vs France)<br>
                   • June 29: Round of 32<br>
                   • July 9: Quarter-final"""
    },
    {
        "nazwa": "AT&T Stadium (Dallas)",
        "coords": [32.7473, -97.0945],
        "grupa": "Group E",
        "info": """<b>AT&T Stadium</b><br>
                   <b>Urban Context:</b> Suburbs (Arlington). Massive mega-structure sitting right between Dallas and Fort Worth metros.<br>
                   <b>Key Matches:</b><br>
                   • June 14: Group Stage (Netherlands vs Japan)<br>
                   • June 17: Group Stage (England vs Croatia)<br>
                   • June 22 & 25: Group Stage Matches<br>
                   • June 28: Group Stage (Jordan vs Argentina)<br>
                   • June 30: Round of 32<br>
                   • July 3: Round of 32<br>
                   • July 6: Round of 16<br>
                   • <b>July 14: Semi-final ⚽</b>"""
    },
    {
        "nazwa": "NRG Stadium (Houston)",
        "coords": [29.6847, -95.4082],
        "grupa": "Group F",
        "info": """<b>NRG Stadium</b><br>
                   <b>Urban Context:</b> Outer urban tier. Located in the Medical Center district, accessible by light rail.<br>
                   <b>Key Matches:</b><br>
                   • June 14: Group Stage (Germany vs Curacao)<br>
                   • June 17, 20 & 23: Group Stage Matches<br>
                   • June 27: Group Stage (Cape Verde vs Saudi Arabia)<br>
                   • June 29: Round of 32<br>
                   • July 4: Round of 16"""
    },
    {
        "nazwa": "Arrowhead Stadium (Kansas City)",
        "coords": [39.0489, -94.4839],
        "grupa": "Group G",
        "info": """<b>Arrowhead Stadium</b><br>
                   <b>Urban Context:</b> Suburbs. Part of a highway-accessible sports complex completely cut off from downtown walkable areas.<br>
                   <b>Key Matches:</b><br>
                   • June 16: Group Stage (Argentina vs Algeria)<br>
                   • June 20, 25 & 28: Group Stage Matches<br>
                   • July 3: Round of 32<br>
                   • July 8: Round of 16"""
    },
    {
        "nazwa": "Lincoln Financial Field (Philadelphia)",
        "coords": [39.9008, -75.1675],
        "grupa": "Group H",
        "info": """<b>Lincoln Financial Field</b><br>
                   <b>Urban Context:</b> South Philadelphia Sports Complex. An urban edge cluster dedicated solely to 4 massive stadiums side-by-side.<br>
                   <b>Key Matches:</b><br>
                   • June 14: Group Stage (Ivory Coast vs Ecuador)<br>
                   • June 19, 22 & 25: Group Stage Matches<br>
                   • June 27: Group Stage (Croatia vs Ghana)<br>
                   • June 30: Round of 32<br>
                   • July 4: Round of 16"""
    },
    {
        "nazwa": "Levi's Stadium (San Francisco Bay Area)",
        "coords": [37.4033, -121.9698],
        "grupa": "Group I",
        "info": """<b>Levi's Stadium</b><br>
                   <b>Urban Context:</b> Deep Suburbs (Santa Clara). 70+ km away from San Francisco proper, nested right in Silicon Valley.<br>
                   <b>Key Matches:</b><br>
                   • June 13: Group Stage (Qatar vs Switzerland)<br>
                   • June 16, 19 & 23: Group Stage Matches<br>
                   • June 26: Group Stage (Paraguay vs Australia)<br>
                   • July 1: Round of 32<br>
                   • July 5: Round of 16"""
    },
    {
        "nazwa": "Lumen Field (Seattle)",
        "coords": [47.5952, -122.3316],
        "grupa": "Group J",
        "info": """<b>Lumen Field</b><br>
                   <b>Urban Context:</b> Pure Downtown (Pioneer Square). Outstanding urban design allowing fans to walk directly from downtown bars into the stands.<br>
                   <b>Key Matches:</b><br>
                   • June 15: Group Stage (Belgium vs Egypt)<br>
                   • June 19, 24 & 27: Group Stage Matches<br>
                   • July 2: Round of 32<br>
                   • July 7: Round of 16"""
    },
    # --- MEXICO ---
    {
        "nazwa": "Estadio Azteca (Mexico City)",
        "coords": [19.3030, -99.1506],
        "grupa": "Group A",
        "info": """<b>Estadio Azteca</b><br>
                   <b>Urban Context:</b> Fully Urbanized (Santa Úrsula). A legendary historic venue swallowed over the decades by the sprawling mega-city.<br>
                   <b>Key Matches:</b><br>
                   • <b>June 11: Opening Match (Mexico vs South Africa) 🇲🇽</b><br>
                   • June 17 & 24: Group Stage Matches<br>
                   • June 30: Round of 32<br>
                   • July 5: Round of 16"""
    },
    {
        "nazwa": "Estadio BBVA (Monterrey)",
        "coords": [25.6692, -100.2444],
        "grupa": "Group B",
        "info": """<b>Estadio BBVA</b><br>
                   <b>Urban Context:</b> Suburban edge (Guadalupe). Famed for its breathtaking, postcard-perfect backdrop of the Cerro de la Silla mountain.<br>
                   <b>Key Matches:</b><br>
                   • June 14: Group Stage (Sweden vs Tunisia)<br>
                   • June 20 & 24: Group Stage Matches<br>
                   • June 29: Round of 32"""
    },
    {
        "nazwa": "Estadio Akron (Guadalajara)",
        "coords": [20.6819, -103.4627],
        "grupa": "Group C",
        "info": """<b>Estadio Akron</b><br>
                   <b>Urban Context:</b> Outer Suburbs (Zapopan). A highly modern, volcano-shaped venue anchoring the western fringe of the metro area.<br>
                   <b>Key Matches:</b><br>
                   • June 11: Group Stage (Korea Republic vs Czechia)<br>
                   • June 18 & 23: Group Stage Matches<br>
                   • June 26: Round of 32"""
    },
    # --- CANADA ---
    {
        "nazwa": "BC Place (Vancouver)",
        "coords": [49.2767, -123.1120],
        "grupa": "Group D",
        "info": """<b>BC Place</b><br>
                   <b>Urban Context:</b> Dense Downtown. Perfectly stitched into Vancouver’s waterfront cityscape and highly walkable.<br>
                   <b>Key Matches:</b><br>
                   • June 13: Group Stage (Australia vs Turkey)<br>
                   • June 18, 21 & 24: Group Stage Matches<br>
                   • June 26: Group Stage (New Zealand vs Belgium)<br>
                   • July 2: Round of 32<br>
                   • July 7: Round of 16"""
    },
    {
        "nazwa": "BMO Field (Toronto)",
        "coords": [43.6328, -79.4186],
        "grupa": "Group E",
        "info": """<b>BMO Field</b><br>
                   <b>Urban Context:</b> Near Downtown / Waterfront tier. Positioned at Exhibition Place, easily accessible via regional rail and streetcars.<br>
                   <b>Key Matches:</b><br>
                   • June 12: Group Stage (Canada opening match)<br>
                   • June 17, 20 & 23: Group Stage Matches<br>
                   • June 25: Group Stage (Norway vs Senegal)<br>
                   • July 1: Round of 32"""
    }
]

# --- DYNAMIC LAYER CREATION WITH HTML COLOR DOTS ---
warstwy_mapy = {}
for nazwa_grupy, info_koloru in kolory_grup.items():
    # Sprytny trik: wstrzykujemy kod HTML z kropką o odpowiednim kolorze przed nazwą grupy!
    html_nazwa_legendy = f'<span style="color:{info_koloru["hex"]}; font-size:15px;">●</span> {nazwa_grupy}'

    # Tworzymy osobną warstwę z tą unikalną, kolorową nazwą
    warstwy_mapy[nazwa_grupy] = folium.FeatureGroup(name=html_nazwa_legendy).add_to(mapa)

# 4. Loop adding markers to their respective colored layers
for stadion in stadiony:
    wlasciwosci_koloru = kolory_grup.get(stadion["grupa"], {"folium": "gray"})

    marker = folium.Marker(
        location=stadion["coords"],
        popup=folium.Popup(stadion["info"], max_width=320),
        tooltip=stadion["nazwa"],
        # ZMIANA: Dodajemy ikonę piłki nożnej z zestawu Font Awesome (fa)
        icon=folium.Icon(color=wlasciwosci_koloru["folium"], icon="trophy", prefix="fa")
    )

    marker.add_to(warstwy_mapy[stadion["grupa"]])

# 5. Add Layer Control panel (Legenda jest teraz wbudowana i rozwinięta na starcie)
folium.LayerControl(collapsed=False).add_to(mapa)

# 6. Save HTML file to Google Colab local storage
mapa.save("world_cup_2026_gis_map.html")

# 7. Display the map directly in Colab
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# # Nowa sekcja
